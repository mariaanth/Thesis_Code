# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import math

from anonymeter.evaluators import SinglingOutEvaluator
from anonymeter.evaluators import LinkabilityEvaluator
from anonymeter.evaluators import InferenceEvaluator

# %%
train = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Linkability_Attack_Generated_Data/High_Cor/High_Cor3/train")
control = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Linkability_Attack_Generated_Data/High_Cor/High_Cor3/control")

shigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Linkability_Attack_Generated_Data/High_Cor/High_Cor3/shigh_cor")
synhigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Linkability_Attack_Generated_Data/High_Cor/High_Cor3/synhigh_cor")

# %%
base_path = "C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Linkability_Attack_Generated_Data/High_Cor/High_Cor3"

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    filename = f"shigh_cor{suffix}.csv"
    full_path = f"{base_path}/{filename}"
    
    try:
        globals()[f"shigh_cor{suffix}"] = pd.read_csv(full_path)
        print(f"Imported: shigh_cor{suffix}")
    except FileNotFoundError:
        print(f"File not found: {filename}")
# Out:
# Imported: shigh_cor099
# Imported: shigh_cor098
# Imported: shigh_cor097
# Imported: shigh_cor096
# Imported: shigh_cor095
# Imported: shigh_cor094
# Imported: shigh_cor093
# Imported: shigh_cor092
# Imported: shigh_cor091
# Imported: shigh_cor090
# Imported: shigh_cor089
# Imported: shigh_cor088
# Imported: shigh_cor087
# Imported: shigh_cor086
# Imported: shigh_cor085
# Imported: shigh_cor084
# Imported: shigh_cor083
# Imported: shigh_cor082
# Imported: shigh_cor081
# Imported: shigh_cor080
# Imported: shigh_cor079
# Imported: shigh_cor078
# Imported: shigh_cor077
# Imported: shigh_cor076
# Imported: shigh_cor075
# Imported: shigh_cor074
# Imported: shigh_cor073
# Imported: shigh_cor072
# Imported: shigh_cor071
# Imported: shigh_cor070

# %% [markdown]
# # Linkability

# %%
aux_cols = [["age","zip_code","gender","education_level"],
            ["ethnicity","marital_status","job","income"]]

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
levaluator1 = LinkabilityEvaluator(ori=train, 
                                 syn=shigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator1.evaluate(n_jobs=-2) 
print(levaluator1.risk())
res = levaluator1.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.7401706408712813, ci=(0.7261652012524376, 0.754176080490125))
# Successs rate of main attack: SuccessRate(value=0.749510379038397, error=0.013419124616392655)
# Successs rate of baseline attack: SuccessRate(value=0.004975404150047087, error=0.002126987349027311)
# Successs rate of control attack: SuccessRate(value=0.03594566140806634, error=0.0057488879332611926)

# %% [markdown]
# ## synthpop

# %%
levaluator2 = LinkabilityEvaluator(ori=train, 
                                 syn=synhigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator2.evaluate(n_jobs=-2) 
print(levaluator2.risk())
res = levaluator2.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.11188859676357643, ci=(0.09961185469111672, 0.12416533883603614))
# Successs rate of main attack: SuccessRate(value=0.14159420028018038, error=0.010793398248166627)
# Successs rate of baseline attack: SuccessRate(value=0.004226123732514363, error=0.001952207461767974)
# Successs rate of control attack: SuccessRate(value=0.033448060016290596, error=0.005551355924083995)

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
linkability_results = []
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]

for suffix in suffixes:  
    syn_varname = f"shigh_cor{suffix}"
    
    if syn_varname in globals():
        syn_data = globals()[syn_varname]
        
        print(f"Evaluating dataset: {syn_varname}")
        
        levaluator = LinkabilityEvaluator(
            ori=train,
            syn=syn_data,
            control=control,
            n_attacks=4000,
            aux_cols=aux_cols,
            n_neighbors=10
        )
        
        levaluator.evaluate(n_jobs=-2)
        
        res = levaluator.results()

        privacy_risk = levaluator.risk()
        print(f"Privacy risk for {syn_varname}: {privacy_risk}")
        
        linkability_results.append({
            "rankcor": int(suffix) / 100,  
            "attack_rate": res.attack_rate.value,  
            "baseline_rate": res.baseline_rate.value, 
            "control_rate": res.control_rate.value,   
            "risk": privacy_risk  
        })

df_link = pd.DataFrame(linkability_results)

df_link = df_link.sort_values(by="rankcor", ascending=False)
# Out:
# Evaluating dataset: shigh_cor099
# Privacy risk for shigh_cor099: PrivacyRisk(value=0.6360701482894204, ci=(0.6205638875109073, 0.6515764090679336))
# Evaluating dataset: shigh_cor098
# Privacy risk for shigh_cor098: PrivacyRisk(value=0.727028653714083, ci=(0.7127921171086529, 0.7412651903195131))
# Evaluating dataset: shigh_cor097
# Privacy risk for shigh_cor097: PrivacyRisk(value=0.5151932165903408, ci=(0.49905178531035843, 0.5313346478703231))
# Evaluating dataset: shigh_cor096
# Privacy risk for shigh_cor096: PrivacyRisk(value=0.560468196327038, ci=(0.5443461362995266, 0.5765902563545495))
# Evaluating dataset: shigh_cor095
# Privacy risk for shigh_cor095: PrivacyRisk(value=0.5621569268981621, ci=(0.5461656734064553, 0.5781481803898689))
# Evaluating dataset: shigh_cor094
# Privacy risk for shigh_cor094: PrivacyRisk(value=0.5425451061090913, ci=(0.5265251113461095, 0.5585651008720732))
# Evaluating dataset: shigh_cor093
# Privacy risk for shigh_cor093: PrivacyRisk(value=0.3774485921306428, ci=(0.36153550770916126, 0.39336167655212434))
# Evaluating dataset: shigh_cor092
# Privacy risk for shigh_cor092: PrivacyRisk(value=0.3795660216801106, ci=(0.3636575328647875, 0.3954745104954337))
# Evaluating dataset: shigh_cor091
# Privacy risk for shigh_cor091: PrivacyRisk(value=0.3772163641904267, ci=(0.36140927751170193, 0.39302345086915147))
# Evaluating dataset: shigh_cor090
# Privacy risk for shigh_cor090: PrivacyRisk(value=0.3251411155849226, ci=(0.30969951535619344, 0.34058271581365174))
# Evaluating dataset: shigh_cor089
# Privacy risk for shigh_cor089: PrivacyRisk(value=0.32840674483192367, ci=(0.3130826584412251, 0.3437308312226222))
# Evaluating dataset: shigh_cor088
# Privacy risk for shigh_cor088: PrivacyRisk(value=0.3342786021146399, ci=(0.31879358408549086, 0.3497636201437889))
# Evaluating dataset: shigh_cor087
# Privacy risk for shigh_cor087: PrivacyRisk(value=0.3353961930233843, ci=(0.31975799954301115, 0.35103438650375746))
# Evaluating dataset: shigh_cor086
# Privacy risk for shigh_cor086: PrivacyRisk(value=0.25441128156636117, ci=(0.23991360855732072, 0.26890895457540165))
# Evaluating dataset: shigh_cor085
# Privacy risk for shigh_cor085: PrivacyRisk(value=0.2979002605879082, ci=(0.2826392079678698, 0.3131613132079466))
# Evaluating dataset: shigh_cor084
# Privacy risk for shigh_cor084: PrivacyRisk(value=0.1909893404221117, ci=(0.1777408264304233, 0.20423785441380007))
# Evaluating dataset: shigh_cor083
# Privacy risk for shigh_cor083: PrivacyRisk(value=0.16130183703776432, ci=(0.14848348203459114, 0.1741201920409375))
# Evaluating dataset: shigh_cor082
# Privacy risk for shigh_cor082: PrivacyRisk(value=0.17927532754288883, ci=(0.1662748009622768, 0.19227585412350087))
# Evaluating dataset: shigh_cor081
# Privacy risk for shigh_cor081: PrivacyRisk(value=0.19862891403899616, ci=(0.18522633378407555, 0.21203149429391677))
# Evaluating dataset: shigh_cor080
# Privacy risk for shigh_cor080: PrivacyRisk(value=0.20153861280937985, ci=(0.18785379262482343, 0.21522343299393626))
# Evaluating dataset: shigh_cor079
# Privacy risk for shigh_cor079: PrivacyRisk(value=0.17386106256547032, ci=(0.16083466589024922, 0.18688745924069142))
# Evaluating dataset: shigh_cor078
# Privacy risk for shigh_cor078: PrivacyRisk(value=0.1597996609194268, ci=(0.14729110477830992, 0.17230821706054367))
# Evaluating dataset: shigh_cor077
# Privacy risk for shigh_cor077: PrivacyRisk(value=0.11606240782272957, ci=(0.10472237965781314, 0.127402435987646))
# Evaluating dataset: shigh_cor076
# Privacy risk for shigh_cor076: PrivacyRisk(value=0.10145132013881732, ci=(0.09065050774867629, 0.11225213252895834))
# Evaluating dataset: shigh_cor075
# Privacy risk for shigh_cor075: PrivacyRisk(value=0.12265356089895771, ci=(0.11127804281157522, 0.1340290789863402))
# Evaluating dataset: shigh_cor074
# Privacy risk for shigh_cor074: PrivacyRisk(value=0.17092182374330425, ci=(0.1580042400137785, 0.18383940747283))
# Evaluating dataset: shigh_cor073
# Privacy risk for shigh_cor073: PrivacyRisk(value=0.13972185845060198, ci=(0.12747747570758897, 0.151966241193615))
# Evaluating dataset: shigh_cor072
# Privacy risk for shigh_cor072: PrivacyRisk(value=0.1540261072133693, ci=(0.14142498108587995, 0.16662723334085863))
# Evaluating dataset: shigh_cor071
# Privacy risk for shigh_cor071: PrivacyRisk(value=0.10374702026504838, ci=(0.09324391280329605, 0.11425012772680071))
# Evaluating dataset: shigh_cor070
# Privacy risk for shigh_cor070: PrivacyRisk(value=0.07054189086457348, ci=(0.061053919157144795, 0.08002986257200216))

# %%
df_link['risk_value'] = df_link['risk'].apply(lambda x: x.value)
df_link['risk_ci_lower'] = df_link['risk'].apply(lambda x: x.ci[0])
df_link['risk_ci_upper'] = df_link['risk'].apply(lambda x: x.ci[1])

# %%
risk1 = levaluator1.risk()
risk2 = levaluator2.risk()

row1 = {
    'rankcor': 1.00,  
    'risk_value': risk1.value,
    'risk_ci_lower': risk1.ci[0],
    'risk_ci_upper': risk1.ci[1]
}

df_link_extended = pd.concat([df_link, pd.DataFrame([row1])], ignore_index=True)
df_link_extended = df_link_extended.sort_values(by='rankcor', ascending=False)

plt.figure(figsize=(8, 6))
sns.lineplot(
    x='rankcor',
    y='risk_value',
    data=df_link_extended,
    marker='o',
    label='Synthesizer rankcor = [0.7,1.0]'
)

plt.fill_between(
    df_link_extended['rankcor'],
    df_link_extended['risk_ci_lower'],
    df_link_extended['risk_ci_upper'],
    alpha=0.3
)

plt.axhline(y=risk2.value, color='green', linestyle='--', label='Synthpop')
plt.fill_between(
    df_link_extended['rankcor'],
    risk2.ci[0],
    risk2.ci[1],
    color='green',
    alpha=0.1
)

plt.xlabel('Rank Correlation')
plt.ylabel('Privacy Risk')
plt.title('Linkability Risk vs Rank Correlation')
plt.legend()
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
columns = train.columns
results1 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator1 = InferenceEvaluator(ori=train, 
                                   syn=shigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=2000)
    ievaluator1.evaluate(n_jobs=-2)
    results1.append((secret, ievaluator1.results()))

print(ievaluator1.risk())
# Out:
# PrivacyRisk(value=0.9546411925116308, ci=(0.9448554209878519, 0.9644269640354097))

# %% [markdown]
# ## synthpop

# %%
columns = train.columns
results3 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator3 = InferenceEvaluator(ori=train, 
                                   syn=synhigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=1000)
    ievaluator3.evaluate(n_jobs=-2)
    results3.append((secret, ievaluator3.results()))

print(ievaluator3.risk())
# Out:
# PrivacyRisk(value=0.10491256155144377, ci=(0.0689240483182194, 0.14090107478466812))

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
columns = train.columns

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    
    syn_data_varname = f"shigh_cor{suffix}"
    results_varname = f"results{suffix}"
    
    if syn_data_varname in globals():
        syn_data = globals()[syn_data_varname]
        results_list = []

        print(f"\nRunning inference attacks on: {syn_data_varname}")
        
        for secret in columns:
            aux_cols = [col for col in columns if col != secret]
            
            ievaluator = InferenceEvaluator(
                ori=train,
                syn=syn_data,
                control=control,
                aux_cols=aux_cols,
                secret=secret,
                n_attacks=2000
            )
            ievaluator.evaluate(n_jobs=-2)
            results_list.append((secret, ievaluator.results()))
        
        globals()[results_varname] = results_list

        print(f"Risk for {syn_data_varname}: {ievaluator.risk()}")
    else:
        print(f"{syn_data_varname} not found in globals.")
# Out:
# Running inference attacks on: shigh_cor099
# Risk for shigh_cor099: PrivacyRisk(value=0.8891185898491973, ci=(0.8742442965217677, 0.903992883176627))
#
# Running inference attacks on: shigh_cor098
# Risk for shigh_cor098: PrivacyRisk(value=0.7993519755430113, ci=(0.7800453258360365, 0.8186586252499861))
#
# Running inference attacks on: shigh_cor097
# Risk for shigh_cor097: PrivacyRisk(value=0.7420427067139891, ci=(0.7206886053597157, 0.7633968080682625))
#
# Running inference attacks on: shigh_cor096
# Risk for shigh_cor096: PrivacyRisk(value=0.6863505480324278, ci=(0.6633605097865943, 0.7093405862782612))
#
# Running inference attacks on: shigh_cor095
# Risk for shigh_cor095: PrivacyRisk(value=0.6180050503509832, ci=(0.5939288873570827, 0.6420812133448837))
#
# Running inference attacks on: shigh_cor094
# Risk for shigh_cor094: PrivacyRisk(value=0.6505425136195262, ci=(0.6267860295529635, 0.6742989976860889))
#
# Running inference attacks on: shigh_cor093
# Risk for shigh_cor093: PrivacyRisk(value=0.5033893961696182, ci=(0.47776721249415466, 0.5290115798450817))
#
# Running inference attacks on: shigh_cor092
# Risk for shigh_cor092: PrivacyRisk(value=0.47309133938336073, ci=(0.4475677302785637, 0.49861494848815774))
#
# Running inference attacks on: shigh_cor091
# Risk for shigh_cor091: PrivacyRisk(value=0.4250747740089386, ci=(0.39903840778485006, 0.4511111402330272))
#
# Running inference attacks on: shigh_cor090
# Risk for shigh_cor090: PrivacyRisk(value=0.36410434406964065, ci=(0.3384683429827265, 0.3897403451565548))
#
# Running inference attacks on: shigh_cor089
# Risk for shigh_cor089: PrivacyRisk(value=0.3615758564520029, ci=(0.3355832756444209, 0.3875684372595849))
#
# Running inference attacks on: shigh_cor088
# Risk for shigh_cor088: PrivacyRisk(value=0.378038443588096, ci=(0.3526242609995032, 0.4034526261766888))
#
# Running inference attacks on: shigh_cor087
# Risk for shigh_cor087: PrivacyRisk(value=0.3557580958846132, ci=(0.3295259889880764, 0.38199020278115003))
#
# Running inference attacks on: shigh_cor086
# Risk for shigh_cor086: PrivacyRisk(value=0.28736879030840484, ci=(0.2624953695340304, 0.3122422110827793))
#
# Running inference attacks on: shigh_cor085
# Risk for shigh_cor085: PrivacyRisk(value=0.32359229782013, ci=(0.2980816809966793, 0.3491029146435807))
#
# Running inference attacks on: shigh_cor084
# Risk for shigh_cor084: PrivacyRisk(value=0.19294309495266646, ci=(0.16955834560049315, 0.21632784430483976))
#
# Running inference attacks on: shigh_cor083
# Risk for shigh_cor083: PrivacyRisk(value=0.17635050429108018, ci=(0.15334883012868722, 0.19935217845347314))
#
# Running inference attacks on: shigh_cor082
# Risk for shigh_cor082: PrivacyRisk(value=0.2418298225139358, ci=(0.21661677465372453, 0.2670428703741471))
#
# Running inference attacks on: shigh_cor081
# Risk for shigh_cor081: PrivacyRisk(value=0.22217118539348799, ci=(0.1981000220861595, 0.24624234870081646))
#
# Running inference attacks on: shigh_cor080
# Risk for shigh_cor080: PrivacyRisk(value=0.20000868756525975, ci=(0.1759946380359823, 0.22402273709453718))
#
# Running inference attacks on: shigh_cor079
# Risk for shigh_cor079: PrivacyRisk(value=0.19603412445791513, ci=(0.1733781462960398, 0.21869010261979047))
#
# Running inference attacks on: shigh_cor078
# Risk for shigh_cor078: PrivacyRisk(value=0.15268657474543162, ci=(0.130279741296652, 0.17509340819421124))
#
# Running inference attacks on: shigh_cor077
# Risk for shigh_cor077: PrivacyRisk(value=0.11955276091429848, ci=(0.09829532694558431, 0.14081019488301263))
#
# Running inference attacks on: shigh_cor076
# Risk for shigh_cor076: PrivacyRisk(value=0.12212623514658393, ci=(0.10123913888816573, 0.14301333140500214))
#
# Running inference attacks on: shigh_cor075
# Risk for shigh_cor075: PrivacyRisk(value=0.12620855862399005, ci=(0.10534758029758379, 0.14706953695039632))
#
# Running inference attacks on: shigh_cor074
# Risk for shigh_cor074: PrivacyRisk(value=0.16948041000110559, ci=(0.14652532197248447, 0.1924354980297267))
#
# Running inference attacks on: shigh_cor073
# Risk for shigh_cor073: PrivacyRisk(value=0.15309038302033712, ci=(0.12946816697084762, 0.17671259906982661))
#
# Running inference attacks on: shigh_cor072
# Risk for shigh_cor072: PrivacyRisk(value=0.16394152772763476, ci=(0.14066890853091973, 0.1872141469243498))
#
# Running inference attacks on: shigh_cor071
# Risk for shigh_cor071: PrivacyRisk(value=0.10634179902100599, ci=(0.08564466850942443, 0.12703892953258755))
#
# Running inference attacks on: shigh_cor070
# Risk for shigh_cor070: PrivacyRisk(value=0.08450306706563712, ci=(0.06422584872540953, 0.10478028540586472))

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
num_plots = len(suffixes)

cols = 4
rows = math.ceil(num_plots / cols)
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = axes.flatten()  

for idx, suffix in enumerate(suffixes):
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        risks = [res[1].risk().value for res in results]
        secrets = [res[0] for res in results]

        ax = axes[idx]
        ax.bar(x=secrets, height=risks, alpha=0.5, ecolor='black', capsize=10)
        ax.set_xticklabels(secrets, rotation=45, ha='right')
        ax.set_ylabel("Measured inference risk")
        ax.set_xlabel("Secret column")
        ax.set_ylim(0, 1)
        ax.set_title(f"rankcor = 0.{suffix[-2:]}")
    else:
        axes[idx].axis("off") 
        
for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_5996\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
rankcors = [int(suffix) / 100 for suffix in suffixes]

secret_columns = [res[0] for res in globals()[f"results{suffixes[0]}"]]

risk_by_secret = {secret: [] for secret in secret_columns}

for suffix in suffixes:
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        for secret, result in results:
            risk_by_secret[secret].append(result.risk().value)
    else:
        for secret in secret_columns:
            risk_by_secret[secret].append(None)  

plt.figure(figsize=(12, 7))

for secret, risks in risk_by_secret.items():
    plt.plot(rankcors, risks, marker='o', label=secret)

plt.xlabel("Rank correlation (rankcor)")
plt.ylabel("Measured inference risk")
plt.title("Inference risk per secret column across decreasing rankcor")
plt.xticks(rankcors)
plt.ylim(0, 1)
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
rankcors = [int(suffix) / 100 for suffix in suffixes]
rankcors_full = [1.00] + rankcors  

risk1_dict = {secret: result.risk().value for secret, result in results1}
risk3_dict = {secret: result.risk().value for secret, result in results3}

risk_by_secret_full = {}

for secret in secret_columns:
    risk_vals = risk_by_secret[secret]
    
    if secret in risk1_dict:
        risk_vals_full = [risk1_dict[secret]] + risk_vals
    else:
        risk_vals_full = [None] + risk_vals
    
    risk_by_secret_full[secret] = risk_vals_full

n = len(secret_columns)
cols = 4
rows = (n + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

for idx, secret in enumerate(secret_columns):
    ax = axes[idx]
    
    ax.plot(rankcors_full, risk_by_secret_full[secret], marker='o', color='steelblue', label='Synthesizer with rankcor = [0.7,1.0]')

    if secret in risk3_dict:
        ax.axhline(y=risk3_dict[secret], color='green', linestyle='--', label='Synthpop')
    
    ax.set_title(f"Secret: {secret}")
    ax.set_ylim(0, 1)
    ax.set_xlabel("Rank Correlation")
    ax.set_ylabel("Privacy Risk")
    ax.grid(True)

    if idx == 0:
        ax.legend()

for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
