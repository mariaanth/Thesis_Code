# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import math

from anonymeter.evaluators import SinglingOutEvaluator
from anonymeter.evaluators import LinkabilityEvaluator
from anonymeter.evaluators import InferenceEvaluator

# %%
train = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/train")
control = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/control")

shigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/shigh_cor")
synhigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/synhigh_cor")

# %%
base_path = "C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4"

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    filename = f"shigh_cor{suffix}.csv"
    full_path = f"{base_path}/{filename}"
    
    try:
        globals()[f"shigh_cor{suffix}"] = pd.read_csv(full_path)
        print(f"Imported: shigh_cor{suffix}")
    except FileNotFoundError:
        print(f"File not found: {filename}")
# Out:
# Imported: shigh_cor099
# Imported: shigh_cor098
# Imported: shigh_cor097
# Imported: shigh_cor096
# Imported: shigh_cor095
# Imported: shigh_cor094
# Imported: shigh_cor093
# Imported: shigh_cor092
# Imported: shigh_cor091
# Imported: shigh_cor090
# Imported: shigh_cor089
# Imported: shigh_cor088
# Imported: shigh_cor087
# Imported: shigh_cor086
# Imported: shigh_cor085
# Imported: shigh_cor084
# Imported: shigh_cor083
# Imported: shigh_cor082
# Imported: shigh_cor081
# Imported: shigh_cor080
# Imported: shigh_cor079
# Imported: shigh_cor078
# Imported: shigh_cor077
# Imported: shigh_cor076
# Imported: shigh_cor075
# Imported: shigh_cor074
# Imported: shigh_cor073
# Imported: shigh_cor072
# Imported: shigh_cor071
# Imported: shigh_cor070

# %% [markdown]
# # Linkability

# %%
aux_cols = [["age","zip_code","gender","education_level"],
            ["ethnicity","marital_status","job","income"]]

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
levaluator1 = LinkabilityEvaluator(ori=train, 
                                 syn=shigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator1.evaluate(n_jobs=-2) 
print(levaluator1.risk())
res = levaluator1.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.7687038514395118, ci=(0.7551685450171621, 0.7822391578618615))
# Successs rate of main attack: SuccessRate(value=0.7789820754613509, error=0.012849695660443076)
# Successs rate of baseline attack: SuccessRate(value=0.004975404150047087, error=0.002126987349027311)
# Successs rate of control attack: SuccessRate(value=0.044437506140103875, error=0.0063678437606957605)

# %% [markdown]
# ## synthpop

# %%
levaluator2 = LinkabilityEvaluator(ori=train, 
                                 syn=synhigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator2.evaluate(n_jobs=-2) 
print(levaluator2.risk())
res = levaluator2.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.1188654838596886, ci=(0.10640620789732841, 0.1313247598220488))
# Successs rate of main attack: SuccessRate(value=0.1483377240379749, error=0.011004363615585626)
# Successs rate of baseline attack: SuccessRate(value=0.003227083175804064, error=0.0016908050193431565)
# Successs rate of control attack: SuccessRate(value=0.033448060016290596, error=0.005551355924083995)

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
linkability_results = []
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]

for suffix in suffixes:  
    syn_varname = f"shigh_cor{suffix}"
    
    if syn_varname in globals():
        syn_data = globals()[syn_varname]
        
        print(f"Evaluating dataset: {syn_varname}")
        
        levaluator = LinkabilityEvaluator(
            ori=train,
            syn=syn_data,
            control=control,
            n_attacks=4000,
            aux_cols=aux_cols,
            n_neighbors=10
        )
        
        levaluator.evaluate(n_jobs=-2)
        
        res = levaluator.results()

        privacy_risk = levaluator.risk()
        print(f"Privacy risk for {syn_varname}: {privacy_risk}")
        
        linkability_results.append({
            "rankcor": int(suffix) / 100,  
            "attack_rate": res.attack_rate.value,  
            "baseline_rate": res.baseline_rate.value, 
            "control_rate": res.control_rate.value,   
            "risk": privacy_risk  
        })

df_link = pd.DataFrame(linkability_results)

df_link = df_link.sort_values(by="rankcor", ascending=False)
# Out:
# Evaluating dataset: shigh_cor099
# Privacy risk for shigh_cor099: PrivacyRisk(value=0.6853869397315804, ci=(0.6704604985585443, 0.7003133809046165))
# Evaluating dataset: shigh_cor098
# Privacy risk for shigh_cor098: PrivacyRisk(value=0.6434219887848729, ci=(0.6281117203406641, 0.6587322572290817))
# Evaluating dataset: shigh_cor097
# Privacy risk for shigh_cor097: PrivacyRisk(value=0.5865479742078347, ci=(0.5707055258441946, 0.6023904225714747))
# Evaluating dataset: shigh_cor096
# Privacy risk for shigh_cor096: PrivacyRisk(value=0.6125671619655598, ci=(0.5969732699840976, 0.628161053947022))
# Evaluating dataset: shigh_cor095
# Privacy risk for shigh_cor095: PrivacyRisk(value=0.5765187277123884, ci=(0.5606328342951965, 0.5924046211295804))
# Evaluating dataset: shigh_cor094
# Privacy risk for shigh_cor094: PrivacyRisk(value=0.5115964352603212, ci=(0.49543430630481644, 0.5277585642158259))
# Evaluating dataset: shigh_cor093
# Privacy risk for shigh_cor093: PrivacyRisk(value=0.4713570895081111, ci=(0.4550777792445613, 0.48763639977166096))
# Evaluating dataset: shigh_cor092
# Privacy risk for shigh_cor092: PrivacyRisk(value=0.4844850924862611, ci=(0.46835628291325776, 0.5006139020592644))
# Evaluating dataset: shigh_cor091
# Privacy risk for shigh_cor091: PrivacyRisk(value=0.3788034040064843, ci=(0.36283483813349476, 0.3947719698794739))
# Evaluating dataset: shigh_cor090
# Privacy risk for shigh_cor090: PrivacyRisk(value=0.36707657291969775, ci=(0.35123162819834297, 0.38292151764105253))
# Evaluating dataset: shigh_cor089
# Privacy risk for shigh_cor089: PrivacyRisk(value=0.3724160536575812, ci=(0.3566535477250623, 0.38817855959010006))
# Evaluating dataset: shigh_cor088
# Privacy risk for shigh_cor088: PrivacyRisk(value=0.3601400072768592, ci=(0.34454945006786275, 0.3757305644858556))
# Evaluating dataset: shigh_cor087
# Privacy risk for shigh_cor087: PrivacyRisk(value=0.2301654109078439, ci=(0.2160892840350505, 0.24424153778063729))
# Evaluating dataset: shigh_cor086
# Privacy risk for shigh_cor086: PrivacyRisk(value=0.2946511291746738, ci=(0.2795150153016389, 0.30978724304770866))
# Evaluating dataset: shigh_cor085
# Privacy risk for shigh_cor085: PrivacyRisk(value=0.19617255446080864, ci=(0.1826569933629988, 0.2096881155586185))
# Evaluating dataset: shigh_cor084
# Privacy risk for shigh_cor084: PrivacyRisk(value=0.16144167242452628, ci=(0.1487563975131124, 0.17412694733594017))
# Evaluating dataset: shigh_cor083
# Privacy risk for shigh_cor083: PrivacyRisk(value=0.24219641552807747, ci=(0.22777584521260377, 0.25661698584355114))
# Evaluating dataset: shigh_cor082
# Privacy risk for shigh_cor082: PrivacyRisk(value=0.11767940104827078, ci=(0.10623622263448868, 0.12912257946205288))
# Evaluating dataset: shigh_cor081
# Privacy risk for shigh_cor081: PrivacyRisk(value=0.14005385258966274, ci=(0.12788289337186287, 0.1522248118074626))
# Evaluating dataset: shigh_cor080
# Privacy risk for shigh_cor080: PrivacyRisk(value=0.14173712869821695, ci=(0.1299182981373325, 0.1535559592591014))
# Evaluating dataset: shigh_cor079
# Privacy risk for shigh_cor079: PrivacyRisk(value=0.13086053095811814, ci=(0.11868164337923091, 0.14303941853700536))
# Evaluating dataset: shigh_cor078
# Privacy risk for shigh_cor078: PrivacyRisk(value=0.19121041854872856, ci=(0.17775184711990402, 0.2046689899775531))
# Evaluating dataset: shigh_cor077
# Privacy risk for shigh_cor077: PrivacyRisk(value=0.10204810470931797, ci=(0.09078391847278508, 0.11331229094585085))
# Evaluating dataset: shigh_cor076
# Privacy risk for shigh_cor076: PrivacyRisk(value=0.12532092059685976, ci=(0.11365458746555304, 0.13698725372816647))
# Evaluating dataset: shigh_cor075
# Privacy risk for shigh_cor075: PrivacyRisk(value=0.20107576917448003, ci=(0.18751877086591107, 0.214632767483049))
# Evaluating dataset: shigh_cor074
# Privacy risk for shigh_cor074: PrivacyRisk(value=0.09883031949508454, ci=(0.08797879397368828, 0.1096818450164808))
# Evaluating dataset: shigh_cor073
# Privacy risk for shigh_cor073: PrivacyRisk(value=0.14198604519947117, ci=(0.12981386075687293, 0.1541582296420694))
# Evaluating dataset: shigh_cor072
# Privacy risk for shigh_cor072: PrivacyRisk(value=0.0881623446852257, ci=(0.0778833474577849, 0.0984413419126665))
# Evaluating dataset: shigh_cor071
# Privacy risk for shigh_cor071: PrivacyRisk(value=0.1349658005649589, ci=(0.12304719430701276, 0.14688440682290507))
# Evaluating dataset: shigh_cor070
# Privacy risk for shigh_cor070: PrivacyRisk(value=0.09853288013158769, ci=(0.0881313670496799, 0.10893439321349548))

# %%
df_link['risk_value'] = df_link['risk'].apply(lambda x: x.value)
df_link['risk_ci_lower'] = df_link['risk'].apply(lambda x: x.ci[0])
df_link['risk_ci_upper'] = df_link['risk'].apply(lambda x: x.ci[1])

# %%
risk1 = levaluator1.risk()
risk2 = levaluator2.risk()

row1 = {
    'rankcor': 1.00,  
    'risk_value': risk1.value,
    'risk_ci_lower': risk1.ci[0],
    'risk_ci_upper': risk1.ci[1]
}

df_link_extended = pd.concat([df_link, pd.DataFrame([row1])], ignore_index=True)
df_link_extended = df_link_extended.sort_values(by='rankcor', ascending=False)

plt.figure(figsize=(8, 6))
sns.lineplot(
    x='rankcor',
    y='risk_value',
    data=df_link_extended,
    marker='o',
    label='Synthesizer with rankcor = [0.7,1.0]'
)

plt.fill_between(
    df_link_extended['rankcor'],
    df_link_extended['risk_ci_lower'],
    df_link_extended['risk_ci_upper'],
    alpha=0.3
)

plt.axhline(y=risk2.value, color='green', linestyle='--', label='Synthpop')
plt.fill_between(
    df_link_extended['rankcor'],
    risk2.ci[0],
    risk2.ci[1],
    color='green',
    alpha=0.1
)

plt.xlabel('Rank Correlation')
plt.ylabel('Privacy Risk')
plt.title('Linkability Risk vs Rank Correlation')
plt.legend()
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
columns = train.columns
results1 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator1 = InferenceEvaluator(ori=train, 
                                   syn=shigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=2000)
    ievaluator1.evaluate(n_jobs=-2)
    results1.append((secret, ievaluator1.results()))

print(ievaluator1.risk())
# Out:
# PrivacyRisk(value=0.8913703233821583, ci=(0.8764921516203262, 0.9062484951439903))

# %% [markdown]
# ## synthpop

# %%
columns = train.columns
results3 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator3 = InferenceEvaluator(ori=train, 
                                   syn=synhigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=1000)
    ievaluator3.evaluate(n_jobs=-2)
    results3.append((secret, ievaluator3.results()))

print(ievaluator3.risk())
# Out:
# PrivacyRisk(value=0.08552654474302482, ci=(0.04995972835872454, 0.1210933611273251))

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
columns = train.columns

for i in range(99, 69, -1): 
    suffix = f"{i:03d}"  
    
    syn_data_varname = f"shigh_cor{suffix}"
    results_varname = f"results{suffix}"
    
    if syn_data_varname in globals():
        syn_data = globals()[syn_data_varname]
        results_list = []

        print(f"\nRunning inference attacks on: {syn_data_varname}")
        
        for secret in columns:
            aux_cols = [col for col in columns if col != secret]
            
            ievaluator = InferenceEvaluator(
                ori=train,
                syn=syn_data,
                control=control,
                aux_cols=aux_cols,
                secret=secret,
                n_attacks=2000
            )
            ievaluator.evaluate(n_jobs=-2)
            results_list.append((secret, ievaluator.results()))
        
        globals()[results_varname] = results_list

        print(f"Risk for {syn_data_varname}: {ievaluator.risk()}")
    else:
        print(f"{syn_data_varname} not found in globals.")
# Out:
# Running inference attacks on: shigh_cor099
# Risk for shigh_cor099: PrivacyRisk(value=0.8809514721040738, ci=(0.8655724010456587, 0.8963305431624888))
#
# Running inference attacks on: shigh_cor098
# Risk for shigh_cor098: PrivacyRisk(value=0.7945409179891658, ci=(0.7749896616725902, 0.8140921743057414))
#
# Running inference attacks on: shigh_cor097
# Risk for shigh_cor097: PrivacyRisk(value=0.7052770283500035, ci=(0.6828632993165928, 0.7276907573834142))
#
# Running inference attacks on: shigh_cor096
# Risk for shigh_cor096: PrivacyRisk(value=0.6923823714214437, ci=(0.6697464585378189, 0.7150182843050684))
#
# Running inference attacks on: shigh_cor095
# Risk for shigh_cor095: PrivacyRisk(value=0.6161091955488233, ci=(0.5918108929633517, 0.6404074981342949))
#
# Running inference attacks on: shigh_cor094
# Risk for shigh_cor094: PrivacyRisk(value=0.5781420359052958, ci=(0.5532999770526854, 0.6029840947579062))
#
# Running inference attacks on: shigh_cor093
# Risk for shigh_cor093: PrivacyRisk(value=0.5268990860029312, ci=(0.501586778398077, 0.5522113936077855))
#
# Running inference attacks on: shigh_cor092
# Risk for shigh_cor092: PrivacyRisk(value=0.5449650648400397, ci=(0.5195926294208395, 0.5703375002592399))
#
# Running inference attacks on: shigh_cor091
# Risk for shigh_cor091: PrivacyRisk(value=0.4537498424102988, ci=(0.427757819570322, 0.4797418652502756))
#
# Running inference attacks on: shigh_cor090
# Risk for shigh_cor090: PrivacyRisk(value=0.3862925410279501, ci=(0.36058082014624504, 0.4120042619096551))
#
# Running inference attacks on: shigh_cor089
# Risk for shigh_cor089: PrivacyRisk(value=0.4237754657077608, ci=(0.39819357620870355, 0.4493573552068181))
#
# Running inference attacks on: shigh_cor088
# Risk for shigh_cor088: PrivacyRisk(value=0.40265782118972165, ci=(0.3772040312173719, 0.4281116111620714))
#
# Running inference attacks on: shigh_cor087
# Risk for shigh_cor087: PrivacyRisk(value=0.2640160447629208, ci=(0.2386202062522538, 0.2894118832735878))
#
# Running inference attacks on: shigh_cor086
# Risk for shigh_cor086: PrivacyRisk(value=0.3399817305429803, ci=(0.31436645296523735, 0.36559700812072327))
#
# Running inference attacks on: shigh_cor085
# Risk for shigh_cor085: PrivacyRisk(value=0.2062112875355582, ci=(0.18255723370801114, 0.22986534136310527))
#
# Running inference attacks on: shigh_cor084
# Risk for shigh_cor084: PrivacyRisk(value=0.16082717154059373, ci=(0.13849237552209492, 0.18316196755909253))
#
# Running inference attacks on: shigh_cor083
# Risk for shigh_cor083: PrivacyRisk(value=0.2961053783422897, ci=(0.27089324287563105, 0.3213175138089484))
#
# Running inference attacks on: shigh_cor082
# Risk for shigh_cor082: PrivacyRisk(value=0.12644861113576994, ci=(0.10343161804286753, 0.14946560422867233))
#
# Running inference attacks on: shigh_cor081
# Risk for shigh_cor081: PrivacyRisk(value=0.22035770831636164, ci=(0.1965080311537366, 0.24420738547898668))
#
# Running inference attacks on: shigh_cor080
# Risk for shigh_cor080: PrivacyRisk(value=0.12979752964222904, ci=(0.10700298395267926, 0.15259207533177882))
#
# Running inference attacks on: shigh_cor079
# Risk for shigh_cor079: PrivacyRisk(value=0.15630841533310466, ci=(0.13267051514004052, 0.1799463155261688))
#
# Running inference attacks on: shigh_cor078
# Risk for shigh_cor078: PrivacyRisk(value=0.19844801064148213, ci=(0.17338412605274006, 0.2235118952302242))
#
# Running inference attacks on: shigh_cor077
# Risk for shigh_cor077: PrivacyRisk(value=0.13918412778513967, ci=(0.11616589148321592, 0.1622023640870634))
#
# Running inference attacks on: shigh_cor076
# Risk for shigh_cor076: PrivacyRisk(value=0.12513959177724443, ci=(0.10396094075036519, 0.14631824280412367))
#
# Running inference attacks on: shigh_cor075
# Risk for shigh_cor075: PrivacyRisk(value=0.17482894930945586, ci=(0.15096878681064607, 0.19868911180826565))
#
# Running inference attacks on: shigh_cor074
# Risk for shigh_cor074: PrivacyRisk(value=0.14519386057800002, ci=(0.1226193310393539, 0.16776839011664613))
#
# Running inference attacks on: shigh_cor073
# Risk for shigh_cor073: PrivacyRisk(value=0.15684826038620167, ci=(0.1344369544149757, 0.17925956635742765))
#
# Running inference attacks on: shigh_cor072
# Risk for shigh_cor072: PrivacyRisk(value=0.09475776847118894, ci=(0.0746609783215801, 0.11485455862079778))
#
# Running inference attacks on: shigh_cor071
# Risk for shigh_cor071: PrivacyRisk(value=0.17589805125602295, ci=(0.15224126128700005, 0.19955484122504585))
#
# Running inference attacks on: shigh_cor070
# Risk for shigh_cor070: PrivacyRisk(value=0.11618525733361158, ci=(0.09625695639195878, 0.1361135582752644))

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
num_plots = len(suffixes)

cols = 4
rows = math.ceil(num_plots / cols)
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = axes.flatten()  

for idx, suffix in enumerate(suffixes):
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        risks = [res[1].risk().value for res in results]
        secrets = [res[0] for res in results]

        ax = axes[idx]
        ax.bar(x=secrets, height=risks, alpha=0.5, ecolor='black', capsize=10)
        ax.set_xticklabels(secrets, rotation=45, ha='right')
        ax.set_ylabel("Measured inference risk")
        ax.set_xlabel("Secret column")
        ax.set_ylim(0, 1)
        ax.set_title(f"rankcor = 0.{suffix[-2:]}")
    else:
        axes[idx].axis("off") 
        
for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_23628\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
rankcors = [int(suffix) / 100 for suffix in suffixes]

secret_columns = [res[0] for res in globals()[f"results{suffixes[0]}"]]

risk_by_secret = {secret: [] for secret in secret_columns}

for suffix in suffixes:
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        for secret, result in results:
            risk_by_secret[secret].append(result.risk().value)
    else:
        for secret in secret_columns:
            risk_by_secret[secret].append(None)  

plt.figure(figsize=(12, 7))

for secret, risks in risk_by_secret.items():
    plt.plot(rankcors, risks, marker='o', label=secret)

plt.xlabel("Rank correlation (rankcor)")
plt.ylabel("Measured inference risk")
plt.title("Inference risk per secret column across decreasing rankcor")
plt.xticks(rankcors)
plt.ylim(0, 1)
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
rankcors = [int(suffix) / 100 for suffix in suffixes]
rankcors_full = [1.00] + rankcors  

risk1_dict = {secret: result.risk().value for secret, result in results1}
risk3_dict = {secret: result.risk().value for secret, result in results3}

risk_by_secret_full = {}

for secret in secret_columns:
    risk_vals = risk_by_secret[secret]
    
    if secret in risk1_dict:
        risk_vals_full = [risk1_dict[secret]] + risk_vals
    else:
        risk_vals_full = [None] + risk_vals
    
    risk_by_secret_full[secret] = risk_vals_full

n = len(secret_columns)
cols = 4
rows = (n + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

for idx, secret in enumerate(secret_columns):
    ax = axes[idx]
    
    ax.plot(rankcors_full, risk_by_secret_full[secret], marker='o', color='steelblue', label='Synthesizer with rankcor = [0.7,1.0]')

    if secret in risk3_dict:
        ax.axhline(y=risk3_dict[secret], color='green', linestyle='--', label='Synthpop')
    
    ax.set_title(f"Secret: {secret}")
    ax.set_ylim(0, 1)
    ax.set_xlabel("Rank Correlation")
    ax.set_ylabel("Privacy Risk")
    ax.grid(True)

    if idx == 0:
        ax.legend()

for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
