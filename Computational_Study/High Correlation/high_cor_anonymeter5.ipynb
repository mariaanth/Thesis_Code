# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import math

from anonymeter.evaluators import SinglingOutEvaluator
from anonymeter.evaluators import LinkabilityEvaluator
from anonymeter.evaluators import InferenceEvaluator

# %%
train = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/train")
control = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/control")

shigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/shigh_cor")
synhigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4/synhigh_cor")

# %%
base_path = "C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor4"

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    filename = f"shigh_cor{suffix}.csv"
    full_path = f"{base_path}/{filename}"
    
    try:
        globals()[f"shigh_cor{suffix}"] = pd.read_csv(full_path)
        print(f"Imported: shigh_cor{suffix}")
    except FileNotFoundError:
        print(f"File not found: {filename}")
# Out:
# Imported: shigh_cor099
# Imported: shigh_cor098
# Imported: shigh_cor097
# Imported: shigh_cor096
# Imported: shigh_cor095
# Imported: shigh_cor094
# Imported: shigh_cor093
# Imported: shigh_cor092
# Imported: shigh_cor091
# Imported: shigh_cor090
# Imported: shigh_cor089
# Imported: shigh_cor088
# Imported: shigh_cor087
# Imported: shigh_cor086
# Imported: shigh_cor085
# Imported: shigh_cor084
# Imported: shigh_cor083
# Imported: shigh_cor082
# Imported: shigh_cor081
# Imported: shigh_cor080
# Imported: shigh_cor079
# Imported: shigh_cor078
# Imported: shigh_cor077
# Imported: shigh_cor076
# Imported: shigh_cor075
# Imported: shigh_cor074
# Imported: shigh_cor073
# Imported: shigh_cor072
# Imported: shigh_cor071
# Imported: shigh_cor070

# %% [markdown]
# # Linkability

# %%
aux_cols = [["age","zip_code","gender","education_level"],
            ["ethnicity","marital_status","job","income"]]

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
levaluator1 = LinkabilityEvaluator(ori=train, 
                                 syn=shigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator1.evaluate(n_jobs=-2) 
print(levaluator1.risk())
res = levaluator1.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.7633108728109949, ci=(0.7496892960605406, 0.7769324495614491))
# Successs rate of main attack: SuccessRate(value=0.7732375922602667, error=0.01296769692081715)
# Successs rate of baseline attack: SuccessRate(value=0.002727562897448915, error=0.001543358850427869)
# Successs rate of control attack: SuccessRate(value=0.04193990474832813, error=0.006193384495130666)

# %% [markdown]
# ## synthpop

# %%
levaluator2 = LinkabilityEvaluator(ori=train, 
                                 syn=synhigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator2.evaluate(n_jobs=-2) 
print(levaluator2.risk())
res = levaluator2.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.11395582256983192, ci=(0.10162433304608379, 0.12628731209358005))
# Successs rate of main attack: SuccessRate(value=0.143592281393601, error=0.010856753281281583)
# Successs rate of baseline attack: SuccessRate(value=0.002727562897448915, error=0.001543358850427869)
# Successs rate of control attack: SuccessRate(value=0.033448060016290596, error=0.005551355924083995)

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
linkability_results = []
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]

for suffix in suffixes:  
    syn_varname = f"shigh_cor{suffix}"
    
    if syn_varname in globals():
        syn_data = globals()[syn_varname]
        
        print(f"Evaluating dataset: {syn_varname}")
        
        levaluator = LinkabilityEvaluator(
            ori=train,
            syn=syn_data,
            control=control,
            n_attacks=4000,
            aux_cols=aux_cols,
            n_neighbors=10
        )
        
        levaluator.evaluate(n_jobs=-2)
        
        res = levaluator.results()

        privacy_risk = levaluator.risk()
        print(f"Privacy risk for {syn_varname}: {privacy_risk}")
        
        linkability_results.append({
            "rankcor": int(suffix) / 100,  
            "attack_rate": res.attack_rate.value,  
            "baseline_rate": res.baseline_rate.value, 
            "control_rate": res.control_rate.value,   
            "risk": privacy_risk  
        })

df_link = pd.DataFrame(linkability_results)

df_link = df_link.sort_values(by="rankcor", ascending=False)
# Out:
# Evaluating dataset: shigh_cor099
# Privacy risk for shigh_cor099: PrivacyRisk(value=0.6943793933689835, ci=(0.6795891800074729, 0.709169606730494))
# Evaluating dataset: shigh_cor098
# Privacy risk for shigh_cor098: PrivacyRisk(value=0.6347528649324068, ci=(0.6192660288899129, 0.6502397009749007))
# Evaluating dataset: shigh_cor097
# Privacy risk for shigh_cor097: PrivacyRisk(value=0.5835395642386281, ci=(0.5676000153738022, 0.5994791131034539))
# Evaluating dataset: shigh_cor096
# Privacy risk for shigh_cor096: PrivacyRisk(value=0.6107507523418351, ci=(0.5950840616559161, 0.626417443027754))
# Evaluating dataset: shigh_cor095
# Privacy risk for shigh_cor095: PrivacyRisk(value=0.5952747651343042, ci=(0.579528432198393, 0.6110210980702154))
# Evaluating dataset: shigh_cor094
# Privacy risk for shigh_cor094: PrivacyRisk(value=0.5209887513733652, ci=(0.5048582090629653, 0.5371192936837651))
# Evaluating dataset: shigh_cor093
# Privacy risk for shigh_cor093: PrivacyRisk(value=0.4733961240395711, ci=(0.45721235620520967, 0.4895798918739325))
# Evaluating dataset: shigh_cor092
# Privacy risk for shigh_cor092: PrivacyRisk(value=0.47441152736853937, ci=(0.4582154174866084, 0.49060763725047035))
# Evaluating dataset: shigh_cor091
# Privacy risk for shigh_cor091: PrivacyRisk(value=0.37658426050357374, ci=(0.3606194281408865, 0.392549092866261))
# Evaluating dataset: shigh_cor090
# Privacy risk for shigh_cor090: PrivacyRisk(value=0.38377354789505136, ci=(0.3678350753508545, 0.3997120204392482))
# Evaluating dataset: shigh_cor089
# Privacy risk for shigh_cor089: PrivacyRisk(value=0.37842051482963696, ci=(0.3627189886700829, 0.394122040989191))
# Evaluating dataset: shigh_cor088
# Privacy risk for shigh_cor088: PrivacyRisk(value=0.3652492842401157, ci=(0.349531933721886, 0.3809666347583454))
# Evaluating dataset: shigh_cor087
# Privacy risk for shigh_cor087: PrivacyRisk(value=0.22757850160092105, ci=(0.21360655114979354, 0.24155045205204856))
# Evaluating dataset: shigh_cor086
# Privacy risk for shigh_cor086: PrivacyRisk(value=0.2824858226955837, ci=(0.2673238973994675, 0.2976477479916999))
# Evaluating dataset: shigh_cor085
# Privacy risk for shigh_cor085: PrivacyRisk(value=0.20357099036750126, ci=(0.19004544866677667, 0.21709653206822585))
# Evaluating dataset: shigh_cor084
# Privacy risk for shigh_cor084: PrivacyRisk(value=0.15803163802366105, ci=(0.14565914058691448, 0.1704041354604076))
# Evaluating dataset: shigh_cor083
# Privacy risk for shigh_cor083: PrivacyRisk(value=0.23968700336582643, ci=(0.22524597726842094, 0.25412802946323193))
# Evaluating dataset: shigh_cor082
# Privacy risk for shigh_cor082: PrivacyRisk(value=0.1274235731248158, ci=(0.11566269291628693, 0.13918445333334467))
# Evaluating dataset: shigh_cor081
# Privacy risk for shigh_cor081: PrivacyRisk(value=0.1421309688200322, ci=(0.12988974119788887, 0.15437219644217554))
# Evaluating dataset: shigh_cor080
# Privacy risk for shigh_cor080: PrivacyRisk(value=0.13651632116957022, ci=(0.12479178258434916, 0.1482408597547913))
# Evaluating dataset: shigh_cor079
# Privacy risk for shigh_cor079: PrivacyRisk(value=0.13389712167910947, ci=(0.1219063868445762, 0.14588785651364272))
# Evaluating dataset: shigh_cor078
# Privacy risk for shigh_cor078: PrivacyRisk(value=0.20403885962224574, ci=(0.1903860173516522, 0.2176917018928393))
# Evaluating dataset: shigh_cor077
# Privacy risk for shigh_cor077: PrivacyRisk(value=0.11311870030149303, ci=(0.10196142764699319, 0.12427597295599287))
# Evaluating dataset: shigh_cor076
# Privacy risk for shigh_cor076: PrivacyRisk(value=0.11715397827078552, ci=(0.10558201641629614, 0.1287259401252749))
# Evaluating dataset: shigh_cor075
# Privacy risk for shigh_cor075: PrivacyRisk(value=0.202965557620483, ci=(0.18934610084477585, 0.21658501439619013))
# Evaluating dataset: shigh_cor074
# Privacy risk for shigh_cor074: PrivacyRisk(value=0.10538556474755166, ci=(0.09455215458738281, 0.11621897490772051))
# Evaluating dataset: shigh_cor073
# Privacy risk for shigh_cor073: PrivacyRisk(value=0.12107524845628032, ci=(0.10933668267280913, 0.1328138142397515))
# Evaluating dataset: shigh_cor072
# Privacy risk for shigh_cor072: PrivacyRisk(value=0.08396921772942721, ci=(0.07397371169331024, 0.09396472376554418))
# Evaluating dataset: shigh_cor071
# Privacy risk for shigh_cor071: PrivacyRisk(value=0.1373976272217504, ci=(0.1253464015488477, 0.14944885289465307))
# Evaluating dataset: shigh_cor070
# Privacy risk for shigh_cor070: PrivacyRisk(value=0.10391469445607296, ci=(0.09309093355079832, 0.1147384553613476))

# %%
df_link['risk_value'] = df_link['risk'].apply(lambda x: x.value)
df_link['risk_ci_lower'] = df_link['risk'].apply(lambda x: x.ci[0])
df_link['risk_ci_upper'] = df_link['risk'].apply(lambda x: x.ci[1])

# %%
risk1 = levaluator1.risk()
risk2 = levaluator2.risk()

row1 = {
    'rankcor': 1.00,  
    'risk_value': risk1.value,
    'risk_ci_lower': risk1.ci[0],
    'risk_ci_upper': risk1.ci[1]
}

df_link_extended = pd.concat([df_link, pd.DataFrame([row1])], ignore_index=True)
df_link_extended = df_link_extended.sort_values(by='rankcor', ascending=False)

plt.figure(figsize=(8, 6))
sns.lineplot(
    x='rankcor',
    y='risk_value',
    data=df_link_extended,
    marker='o',
    label='Synthesizer with rankcor = [0.7,1.0]'
)

plt.fill_between(
    df_link_extended['rankcor'],
    df_link_extended['risk_ci_lower'],
    df_link_extended['risk_ci_upper'],
    alpha=0.3
)

plt.axhline(y=risk2.value, color='green', linestyle='--', label='Synthpop')
plt.fill_between(
    df_link_extended['rankcor'],
    risk2.ci[0],
    risk2.ci[1],
    color='green',
    alpha=0.1
)

plt.xlabel('Rank Correlation')
plt.ylabel('Privacy Risk')
plt.title('Linkability Risk vs Rank Correlation')
plt.legend()
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
columns = train.columns
results1 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator1 = InferenceEvaluator(ori=train, 
                                   syn=shigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=2000)
    ievaluator1.evaluate(n_jobs=-2)
    results1.append((secret, ievaluator1.results()))

print(ievaluator1.risk())
# Out:
# PrivacyRisk(value=0.8883452746513082, ci=(0.8731725086280883, 0.9035180406745281))

# %% [markdown]
# ## synthpop

# %%
columns = train.columns
results3 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator3 = InferenceEvaluator(ori=train, 
                                   syn=synhigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=1000)
    ievaluator3.evaluate(n_jobs=-2)
    results3.append((secret, ievaluator3.results()))

print(ievaluator3.risk())
# Out:
# PrivacyRisk(value=0.09707414799655953, ci=(0.06233671582784869, 0.13181158016527036))

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
columns = train.columns

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    
    syn_data_varname = f"shigh_cor{suffix}"
    results_varname = f"results{suffix}"
    
    if syn_data_varname in globals():
        syn_data = globals()[syn_data_varname]
        results_list = []

        print(f"\nRunning inference attacks on: {syn_data_varname}")
        
        for secret in columns:
            aux_cols = [col for col in columns if col != secret]
            
            ievaluator = InferenceEvaluator(
                ori=train,
                syn=syn_data,
                control=control,
                aux_cols=aux_cols,
                secret=secret,
                n_attacks=2000
            )
            ievaluator.evaluate(n_jobs=-2)
            results_list.append((secret, ievaluator.results()))
        
        globals()[results_varname] = results_list

        print(f"Risk for {syn_data_varname}: {ievaluator.risk()}")
    else:
        print(f"{syn_data_varname} not found in globals.")
# Out:
# Running inference attacks on: shigh_cor099
# Risk for shigh_cor099: PrivacyRisk(value=0.8688073758584408, ci=(0.8526832202242435, 0.8849315314926381))
#
# Running inference attacks on: shigh_cor098
# Risk for shigh_cor098: PrivacyRisk(value=0.7927614565058381, ci=(0.7730201241433693, 0.8125027888683068))
#
# Running inference attacks on: shigh_cor097
# Risk for shigh_cor097: PrivacyRisk(value=0.702888981956606, ci=(0.6803675866274287, 0.7254103772857833))
#
# Running inference attacks on: shigh_cor096
# Risk for shigh_cor096: PrivacyRisk(value=0.6977713631341236, ci=(0.6753286135086791, 0.720214112759568))
#
# Running inference attacks on: shigh_cor095
# Risk for shigh_cor095: PrivacyRisk(value=0.628876768205379, ci=(0.6046655713333283, 0.6530879650774296))
#
# Running inference attacks on: shigh_cor094
# Risk for shigh_cor094: PrivacyRisk(value=0.5780539846085697, ci=(0.5532400717184366, 0.6028678974987028))
#
# Running inference attacks on: shigh_cor093
# Risk for shigh_cor093: PrivacyRisk(value=0.5532757054324049, ci=(0.5282483318175166, 0.5783030790472932))
#
# Running inference attacks on: shigh_cor092
# Risk for shigh_cor092: PrivacyRisk(value=0.532263683742116, ci=(0.5067156204046057, 0.5578117470796262))
#
# Running inference attacks on: shigh_cor091
# Risk for shigh_cor091: PrivacyRisk(value=0.47735749323445104, ci=(0.45160335950847036, 0.5031116269604318))
#
# Running inference attacks on: shigh_cor090
# Risk for shigh_cor090: PrivacyRisk(value=0.3729834922161294, ci=(0.3467085816166949, 0.39925840281556396))
#
# Running inference attacks on: shigh_cor089
# Risk for shigh_cor089: PrivacyRisk(value=0.4013555271400763, ci=(0.3753741603349439, 0.42733689394520863))
#
# Running inference attacks on: shigh_cor088
# Risk for shigh_cor088: PrivacyRisk(value=0.3836088741139951, ci=(0.35782749079250203, 0.4093902574354881))
#
# Running inference attacks on: shigh_cor087
# Risk for shigh_cor087: PrivacyRisk(value=0.29454827815065043, ci=(0.26970709098417295, 0.3193894653171279))
#
# Running inference attacks on: shigh_cor086
# Risk for shigh_cor086: PrivacyRisk(value=0.3282111972004182, ci=(0.3011567597447536, 0.3552656346560828))
#
# Running inference attacks on: shigh_cor085
# Risk for shigh_cor085: PrivacyRisk(value=0.21151603671284996, ci=(0.18734803257998398, 0.23568404084571595))
#
# Running inference attacks on: shigh_cor084
# Risk for shigh_cor084: PrivacyRisk(value=0.1390463589350392, ci=(0.11639344537320902, 0.16169927249686938))
#
# Running inference attacks on: shigh_cor083
# Risk for shigh_cor083: PrivacyRisk(value=0.26273275828576903, ci=(0.2374957405407036, 0.28796977603083446))
#
# Running inference attacks on: shigh_cor082
# Risk for shigh_cor082: PrivacyRisk(value=0.11457679787003765, ci=(0.09091119611051077, 0.13824239962956453))
#
# Running inference attacks on: shigh_cor081
# Risk for shigh_cor081: PrivacyRisk(value=0.24364878948739083, ci=(0.2197941619037679, 0.26750341707101377))
#
# Running inference attacks on: shigh_cor080
# Risk for shigh_cor080: PrivacyRisk(value=0.13515570238268274, ci=(0.11262199245374431, 0.15768941231162115))
#
# Running inference attacks on: shigh_cor079
# Risk for shigh_cor079: PrivacyRisk(value=0.16311599907029456, ci=(0.13974395803364859, 0.18648804010694053))
#
# Running inference attacks on: shigh_cor078
# Risk for shigh_cor078: PrivacyRisk(value=0.23048309710176693, ci=(0.20585868978540645, 0.2551075044181274))
#
# Running inference attacks on: shigh_cor077
# Risk for shigh_cor077: PrivacyRisk(value=0.14682525226988766, ci=(0.12421839789016896, 0.16943210664960634))
#
# Running inference attacks on: shigh_cor076
# Risk for shigh_cor076: PrivacyRisk(value=0.12324852431524126, ci=(0.1016012904227054, 0.14489575820777711))
#
# Running inference attacks on: shigh_cor075
# Risk for shigh_cor075: PrivacyRisk(value=0.22982017234719568, ci=(0.2060754247127393, 0.25356491998165204))
#
# Running inference attacks on: shigh_cor074
# Risk for shigh_cor074: PrivacyRisk(value=0.13850107909607826, ci=(0.11585906068033525, 0.16114309751182126))
#
# Running inference attacks on: shigh_cor073
# Risk for shigh_cor073: PrivacyRisk(value=0.11889762491033386, ci=(0.09700837184808007, 0.14078687797258765))
#
# Running inference attacks on: shigh_cor072
# Risk for shigh_cor072: PrivacyRisk(value=0.1058047192279706, ci=(0.08512195685373017, 0.12648748160221104))
#
# Running inference attacks on: shigh_cor071
# Risk for shigh_cor071: PrivacyRisk(value=0.16830792040745857, ci=(0.1451856959081172, 0.19143014490679994))
#
# Running inference attacks on: shigh_cor070
# Risk for shigh_cor070: PrivacyRisk(value=0.11271844832150814, ci=(0.0923007976701182, 0.13313609897289808))

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
num_plots = len(suffixes)

cols = 4
rows = math.ceil(num_plots / cols)
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = axes.flatten()  

for idx, suffix in enumerate(suffixes):
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        risks = [res[1].risk().value for res in results]
        secrets = [res[0] for res in results]

        ax = axes[idx]
        ax.bar(x=secrets, height=risks, alpha=0.5, ecolor='black', capsize=10)
        ax.set_xticklabels(secrets, rotation=45, ha='right')
        ax.set_ylabel("Measured inference risk")
        ax.set_xlabel("Secret column")
        ax.set_ylim(0, 1)
        ax.set_title(f"rankcor = 0.{suffix[-2:]}")
    else:
        axes[idx].axis("off") 
        
for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_35380\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
rankcors = [int(suffix) / 100 for suffix in suffixes]

secret_columns = [res[0] for res in globals()[f"results{suffixes[0]}"]]

risk_by_secret = {secret: [] for secret in secret_columns}

for suffix in suffixes:
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        for secret, result in results:
            risk_by_secret[secret].append(result.risk().value)
    else:
        for secret in secret_columns:
            risk_by_secret[secret].append(None)  

plt.figure(figsize=(12, 7))

for secret, risks in risk_by_secret.items():
    plt.plot(rankcors, risks, marker='o', label=secret)

plt.xlabel("Rank correlation (rankcor)")
plt.ylabel("Measured inference risk")
plt.title("Inference risk per secret column across decreasing rankcor")
plt.xticks(rankcors)
plt.ylim(0, 1)
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
rankcors = [int(suffix) / 100 for suffix in suffixes]
rankcors_full = [1.00] + rankcors  

risk1_dict = {secret: result.risk().value for secret, result in results1}
risk3_dict = {secret: result.risk().value for secret, result in results3}

risk_by_secret_full = {}

for secret in secret_columns:
    risk_vals = risk_by_secret[secret]
    
    if secret in risk1_dict:
        risk_vals_full = [risk1_dict[secret]] + risk_vals
    else:
        risk_vals_full = [None] + risk_vals
    
    risk_by_secret_full[secret] = risk_vals_full

n = len(secret_columns)
cols = 4
rows = (n + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

for idx, secret in enumerate(secret_columns):
    ax = axes[idx]
    
    ax.plot(rankcors_full, risk_by_secret_full[secret], marker='o', color='steelblue', label='Synthesizer with rankcor = [0.7,1.0]')

    if secret in risk3_dict:
        ax.axhline(y=risk3_dict[secret], color='green', linestyle='--', label='Synthpop')
    
    ax.set_title(f"Secret: {secret}")
    ax.set_ylim(0, 1)
    ax.set_xlabel("Rank Correlation")
    ax.set_ylabel("Privacy Risk")
    ax.grid(True)

    if idx == 0:
        ax.legend()

for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
