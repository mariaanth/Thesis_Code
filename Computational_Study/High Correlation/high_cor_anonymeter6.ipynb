# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import math

from anonymeter.evaluators import SinglingOutEvaluator
from anonymeter.evaluators import LinkabilityEvaluator
from anonymeter.evaluators import InferenceEvaluator

# %%
train = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor6/train")
control = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor6/control")

shigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor6/shigh_cor")
synhigh_cor = pd.read_csv("C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor6/synhigh_cor")

# %%
base_path = "C:/Users/maria/OneDrive/Υπολογιστής/Thesis/Computational_Study/high_cor/High_Cor6"

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    filename = f"shigh_cor{suffix}.csv"
    full_path = f"{base_path}/{filename}"
    
    try:
        globals()[f"shigh_cor{suffix}"] = pd.read_csv(full_path)
        print(f"Imported: shigh_cor{suffix}")
    except FileNotFoundError:
        print(f"File not found: {filename}")
# Out:
# Imported: shigh_cor099
# Imported: shigh_cor098
# Imported: shigh_cor097
# Imported: shigh_cor096
# Imported: shigh_cor095
# Imported: shigh_cor094
# Imported: shigh_cor093
# Imported: shigh_cor092
# Imported: shigh_cor091
# Imported: shigh_cor090
# Imported: shigh_cor089
# Imported: shigh_cor088
# Imported: shigh_cor087
# Imported: shigh_cor086
# Imported: shigh_cor085
# Imported: shigh_cor084
# Imported: shigh_cor083
# Imported: shigh_cor082
# Imported: shigh_cor081
# Imported: shigh_cor080
# Imported: shigh_cor079
# Imported: shigh_cor078
# Imported: shigh_cor077
# Imported: shigh_cor076
# Imported: shigh_cor075
# Imported: shigh_cor074
# Imported: shigh_cor073
# Imported: shigh_cor072
# Imported: shigh_cor071
# Imported: shigh_cor070

# %% [markdown]
# # Linkability

# %%
aux_cols = [["age","zip_code","gender","education_level"],
            ["ethnicity","marital_status","job","income"]]

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
levaluator1 = LinkabilityEvaluator(ori=train, 
                                 syn=shigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator1.evaluate(n_jobs=-2) 
print(levaluator1.risk())
res = levaluator1.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.8332636928880331, ci=(0.8213789219859821, 0.8451484637900842))
# Successs rate of main attack: SuccessRate(value=0.8401733095598566, error=0.011345900325678872)
# Successs rate of baseline attack: SuccessRate(value=0.004475883871691937, error=0.002012184764256809)
# Successs rate of control attack: SuccessRate(value=0.04144038446997298, error=0.006157782814387508)

# %% [markdown]
# ## synthpop

# %%
levaluator2 = LinkabilityEvaluator(ori=train, 
                                 syn=synhigh_cor, 
                                 control=control,
                                 n_attacks=4000,
                                 aux_cols=aux_cols,
                                 n_neighbors=10)

levaluator2.evaluate(n_jobs=-2) 
print(levaluator2.risk())
res = levaluator2.results()

print("Successs rate of main attack:", res.attack_rate)
print("Successs rate of baseline attack:", res.baseline_rate)
print("Successs rate of control attack:", res.control_rate)
# Out:
# PrivacyRisk(value=0.11742175692694443, ci=(0.1050857302178789, 0.12975778363600995))
# Successs rate of main attack: SuccessRate(value=0.14584012264619917, error=0.010927169247441028)
# Successs rate of baseline attack: SuccessRate(value=0.003976363593336788, error=0.00189029643355562)
# Successs rate of control attack: SuccessRate(value=0.03219925932040272, error=0.0054494935162605895)

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
linkability_results = []
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]

for suffix in suffixes:  
    syn_varname = f"shigh_cor{suffix}"
    
    if syn_varname in globals():
        syn_data = globals()[syn_varname]
        
        print(f"Evaluating dataset: {syn_varname}")
        
        levaluator = LinkabilityEvaluator(
            ori=train,
            syn=syn_data,
            control=control,
            n_attacks=4000,
            aux_cols=aux_cols,
            n_neighbors=10
        )
        
        levaluator.evaluate(n_jobs=-2)
        
        res = levaluator.results()

        privacy_risk = levaluator.risk()
        print(f"Privacy risk for {syn_varname}: {privacy_risk}")
        
        linkability_results.append({
            "rankcor": int(suffix) / 100,  
            "attack_rate": res.attack_rate.value,  
            "baseline_rate": res.baseline_rate.value, 
            "control_rate": res.control_rate.value,   
            "risk": privacy_risk  
        })

df_link = pd.DataFrame(linkability_results)

df_link = df_link.sort_values(by="rankcor", ascending=False)
# Out:
# Evaluating dataset: shigh_cor099
# Privacy risk for shigh_cor099: PrivacyRisk(value=0.6882785740953458, ci=(0.6733716441295914, 0.7031855040611001))
# Evaluating dataset: shigh_cor098
# Privacy risk for shigh_cor098: PrivacyRisk(value=0.7619204782424093, ci=(0.7482897231937637, 0.7755512332910548))
# Evaluating dataset: shigh_cor097
# Privacy risk for shigh_cor097: PrivacyRisk(value=0.605071751263424, ci=(0.5893571872879636, 0.6207863152388845))
# Evaluating dataset: shigh_cor096
# Privacy risk for shigh_cor096: PrivacyRisk(value=0.4949570447102325, ci=(0.4786117127473969, 0.5113023766730681))
# Evaluating dataset: shigh_cor095
# Privacy risk for shigh_cor095: PrivacyRisk(value=0.5157973311487013, ci=(0.4995326846580401, 0.5320619776393625))
# Evaluating dataset: shigh_cor094
# Privacy risk for shigh_cor094: PrivacyRisk(value=0.4916315988467988, ci=(0.47540103200904577, 0.5078621656845518))
# Evaluating dataset: shigh_cor093
# Privacy risk for shigh_cor093: PrivacyRisk(value=0.45516218991909085, ci=(0.4389973204735227, 0.471327059364659))
# Evaluating dataset: shigh_cor092
# Privacy risk for shigh_cor092: PrivacyRisk(value=0.327694630881862, ci=(0.31217526496328474, 0.3432139968004393))
# Evaluating dataset: shigh_cor091
# Privacy risk for shigh_cor091: PrivacyRisk(value=0.42398600710593976, ci=(0.40784780624395056, 0.44012420796792895))
# Evaluating dataset: shigh_cor090
# Privacy risk for shigh_cor090: PrivacyRisk(value=0.38898226534706115, ci=(0.3730727776381211, 0.4048917530560012))
# Evaluating dataset: shigh_cor089
# Privacy risk for shigh_cor089: PrivacyRisk(value=0.3476662982124487, ci=(0.3320907551512907, 0.3632418412736067))
# Evaluating dataset: shigh_cor088
# Privacy risk for shigh_cor088: PrivacyRisk(value=0.3023497212054291, ci=(0.28693443390423595, 0.3177650085066222))
# Evaluating dataset: shigh_cor087
# Privacy risk for shigh_cor087: PrivacyRisk(value=0.38545119296344144, ci=(0.36957524134300257, 0.4013271445838803))
# Evaluating dataset: shigh_cor086
# Privacy risk for shigh_cor086: PrivacyRisk(value=0.26993627223980243, ci=(0.25507386939211657, 0.2847986750874883))
# Evaluating dataset: shigh_cor085
# Privacy risk for shigh_cor085: PrivacyRisk(value=0.2182279987396985, ci=(0.20434305553470444, 0.23211294194469256))
# Evaluating dataset: shigh_cor084
# Privacy risk for shigh_cor084: PrivacyRisk(value=0.22217021137866272, ci=(0.20841584712713587, 0.23592457563018956))
# Evaluating dataset: shigh_cor083
# Privacy risk for shigh_cor083: PrivacyRisk(value=0.2488588199657155, ci=(0.23456838708937738, 0.2631492528420536))
# Evaluating dataset: shigh_cor082
# Privacy risk for shigh_cor082: PrivacyRisk(value=0.1862106669295957, ci=(0.17289426549098796, 0.19952706836820344))
# Evaluating dataset: shigh_cor081
# Privacy risk for shigh_cor081: PrivacyRisk(value=0.15717509139424557, ci=(0.14476155233944274, 0.1695886304490484))
# Evaluating dataset: shigh_cor080
# Privacy risk for shigh_cor080: PrivacyRisk(value=0.1928921183606963, ci=(0.17935960572934698, 0.20642463099204564))
# Evaluating dataset: shigh_cor079
# Privacy risk for shigh_cor079: PrivacyRisk(value=0.08152062333870404, ci=(0.07179581344683159, 0.09124543323057649))
# Evaluating dataset: shigh_cor078
# Privacy risk for shigh_cor078: PrivacyRisk(value=0.10267042916021842, ci=(0.09186833420609403, 0.1134725241143428))
# Evaluating dataset: shigh_cor077
# Privacy risk for shigh_cor077: PrivacyRisk(value=0.09590628403655227, ci=(0.08525236952403803, 0.10656019854906651))
# Evaluating dataset: shigh_cor076
# Privacy risk for shigh_cor076: PrivacyRisk(value=0.15549638702276017, ci=(0.1429840190371938, 0.16800875500832654))
# Evaluating dataset: shigh_cor075
# Privacy risk for shigh_cor075: PrivacyRisk(value=0.08005243857789306, ci=(0.0700526985706883, 0.09005217858509781))
# Evaluating dataset: shigh_cor074
# Privacy risk for shigh_cor074: PrivacyRisk(value=0.107733470239724, ci=(0.09695808118186015, 0.11850885929758785))
# Evaluating dataset: shigh_cor073
# Privacy risk for shigh_cor073: PrivacyRisk(value=0.10834399503875179, ci=(0.09729965852577564, 0.11938833155172794))
# Evaluating dataset: shigh_cor072
# Privacy risk for shigh_cor072: PrivacyRisk(value=0.06884471206300169, ci=(0.05966571050781064, 0.07802371361819274))
# Evaluating dataset: shigh_cor071
# Privacy risk for shigh_cor071: PrivacyRisk(value=0.12270656301571542, ci=(0.11100959446327992, 0.13440353156815094))
# Evaluating dataset: shigh_cor070
# Privacy risk for shigh_cor070: PrivacyRisk(value=0.08085593935875664, ci=(0.07078219209379752, 0.09092968662371576))

# %%
df_link['risk_value'] = df_link['risk'].apply(lambda x: x.value)
df_link['risk_ci_lower'] = df_link['risk'].apply(lambda x: x.ci[0])
df_link['risk_ci_upper'] = df_link['risk'].apply(lambda x: x.ci[1])

# %%
risk1 = levaluator1.risk()
risk2 = levaluator2.risk()

row1 = {
    'rankcor': 1.00, 
    'risk_value': risk1.value,
    'risk_ci_lower': risk1.ci[0],
    'risk_ci_upper': risk1.ci[1]
}

df_link_extended = pd.concat([df_link, pd.DataFrame([row1])], ignore_index=True)
df_link_extended = df_link_extended.sort_values(by='rankcor', ascending=False)

plt.figure(figsize=(8, 6))
sns.lineplot(
    x='rankcor',
    y='risk_value',
    data=df_link_extended,
    marker='o',
    label='Synthesizer with rankcor = [0.7,1.0]'
)

plt.fill_between(
    df_link_extended['rankcor'],
    df_link_extended['risk_ci_lower'],
    df_link_extended['risk_ci_upper'],
    alpha=0.3
)

plt.axhline(y=risk2.value, color='green', linestyle='--', label='Synthpop')
plt.fill_between(
    df_link_extended['rankcor'],
    risk2.ci[0],
    risk2.ci[1],
    color='green',
    alpha=0.1
)

plt.xlabel('Rank Correlation')
plt.ylabel('Privacy Risk')
plt.title('Linkability Risk vs Rank Correlation')
plt.legend()
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# ## synthesizer rankcor = 1

# %%
columns = train.columns
results1 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator1 = InferenceEvaluator(ori=train, 
                                   syn=shigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=2000)
    ievaluator1.evaluate(n_jobs=-2)
    results1.append((secret, ievaluator1.results()))

print(ievaluator1.risk())
# Out:
# PrivacyRisk(value=0.9546142378384581, ci=(0.944888275683594, 0.9643401999933222))

# %% [markdown]
# ## synthpop

# %%
columns = train.columns
results3 = []

for secret in columns:
    
    aux_cols = [col for col in columns if col != secret]
    
    ievaluator3 = InferenceEvaluator(ori=train, 
                                   syn=synhigh_cor, 
                                   control=control,
                                   aux_cols=aux_cols,
                                   secret=secret,
                                   n_attacks=1000)
    ievaluator3.evaluate(n_jobs=-2)
    results3.append((secret, ievaluator3.results()))

print(ievaluator3.risk())
# Out:
# PrivacyRisk(value=0.07640371330376881, ci=(0.041049182509560946, 0.11175824409797669))

# %% [markdown]
# ## synthesizer rankcor = [0.70,0.99]

# %%
columns = train.columns

for i in range(99, 69, -1):  
    suffix = f"{i:03d}"  
    
    syn_data_varname = f"shigh_cor{suffix}"
    results_varname = f"results{suffix}"
    
    if syn_data_varname in globals():
        syn_data = globals()[syn_data_varname]
        results_list = []

        print(f"\nRunning inference attacks on: {syn_data_varname}")
        
        for secret in columns:
            aux_cols = [col for col in columns if col != secret]
            
            ievaluator = InferenceEvaluator(
                ori=train,
                syn=syn_data,
                control=control,
                aux_cols=aux_cols,
                secret=secret,
                n_attacks=2000
            )
            ievaluator.evaluate(n_jobs=-2)
            results_list.append((secret, ievaluator.results()))
        
        globals()[results_varname] = results_list

        print(f"Risk for {syn_data_varname}: {ievaluator.risk()}")
    else:
        print(f"{syn_data_varname} not found in globals.")
# Out:
# Running inference attacks on: shigh_cor099
# Risk for shigh_cor099: PrivacyRisk(value=0.858903089933674, ci=(0.8422350131629207, 0.8755711667044274))
#
# Running inference attacks on: shigh_cor098
# Risk for shigh_cor098: PrivacyRisk(value=0.812323318173163, ci=(0.7935755936466388, 0.8310710426996871))
#
# Running inference attacks on: shigh_cor097
# Risk for shigh_cor097: PrivacyRisk(value=0.7068594567790826, ci=(0.6843723613980097, 0.7293465521601554))
#
# Running inference attacks on: shigh_cor096
# Risk for shigh_cor096: PrivacyRisk(value=0.7001440252704202, ci=(0.6778058307707033, 0.722482219770137))
#
# Running inference attacks on: shigh_cor095
# Risk for shigh_cor095: PrivacyRisk(value=0.5873279806322815, ci=(0.5624996757748659, 0.6121562854896971))
#
# Running inference attacks on: shigh_cor094
# Risk for shigh_cor094: PrivacyRisk(value=0.5871409204520861, ci=(0.562612274139507, 0.6116695667646652))
#
# Running inference attacks on: shigh_cor093
# Risk for shigh_cor093: PrivacyRisk(value=0.5065457482587356, ci=(0.48062160541705234, 0.5324698911004188))
#
# Running inference attacks on: shigh_cor092
# Risk for shigh_cor092: PrivacyRisk(value=0.42746562736351934, ci=(0.40123081182678927, 0.4537004429002494))
#
# Running inference attacks on: shigh_cor091
# Risk for shigh_cor091: PrivacyRisk(value=0.4567215689950808, ci=(0.43133021333480415, 0.4821129246553575))
#
# Running inference attacks on: shigh_cor090
# Risk for shigh_cor090: PrivacyRisk(value=0.4191935505685241, ci=(0.3932616024070547, 0.44512549872999346))
#
# Running inference attacks on: shigh_cor089
# Risk for shigh_cor089: PrivacyRisk(value=0.42532537112205304, ci=(0.3994152455072016, 0.4512354967369045))
#
# Running inference attacks on: shigh_cor088
# Risk for shigh_cor088: PrivacyRisk(value=0.34585075333323145, ci=(0.3203202023467403, 0.3713813043197226))
#
# Running inference attacks on: shigh_cor087
# Risk for shigh_cor087: PrivacyRisk(value=0.40337925832586063, ci=(0.3772051493265744, 0.4295533673251469))
#
# Running inference attacks on: shigh_cor086
# Risk for shigh_cor086: PrivacyRisk(value=0.35324931027148687, ci=(0.3276047157433019, 0.37889390479967183))
#
# Running inference attacks on: shigh_cor085
# Risk for shigh_cor085: PrivacyRisk(value=0.2683980659017265, ci=(0.24353021825991467, 0.2932659135435383))
#
# Running inference attacks on: shigh_cor084
# Risk for shigh_cor084: PrivacyRisk(value=0.22787872354141228, ci=(0.20367181886911545, 0.2520856282137091))
#
# Running inference attacks on: shigh_cor083
# Risk for shigh_cor083: PrivacyRisk(value=0.2708336840296916, ci=(0.2456816300302872, 0.295985738029096))
#
# Running inference attacks on: shigh_cor082
# Risk for shigh_cor082: PrivacyRisk(value=0.20990573102287632, ci=(0.18623296232585956, 0.23357849971989308))
#
# Running inference attacks on: shigh_cor081
# Risk for shigh_cor081: PrivacyRisk(value=0.17333355305235265, ci=(0.1507208168759047, 0.1959462892288006))
#
# Running inference attacks on: shigh_cor080
# Risk for shigh_cor080: PrivacyRisk(value=0.23010337200987388, ci=(0.2055797166223678, 0.25462702739737997))
#
# Running inference attacks on: shigh_cor079
# Risk for shigh_cor079: PrivacyRisk(value=0.09894594894376536, ci=(0.0797706856515157, 0.11812121223601503))
#
# Running inference attacks on: shigh_cor078
# Risk for shigh_cor078: PrivacyRisk(value=0.10339698241236626, ci=(0.08255103949239746, 0.12424292533233507))
#
# Running inference attacks on: shigh_cor077
# Risk for shigh_cor077: PrivacyRisk(value=0.12580147152697835, ci=(0.10556004461106645, 0.14604289844289026))
#
# Running inference attacks on: shigh_cor076
# Risk for shigh_cor076: PrivacyRisk(value=0.15903644577511208, ci=(0.13681510524683557, 0.1812577863033886))
#
# Running inference attacks on: shigh_cor075
# Risk for shigh_cor075: PrivacyRisk(value=0.09214488042222468, ci=(0.07104354751324396, 0.11324621333120541))
#
# Running inference attacks on: shigh_cor074
# Risk for shigh_cor074: PrivacyRisk(value=0.09946660471849829, ci=(0.07886361629020727, 0.1200695931467893))
#
# Running inference attacks on: shigh_cor073
# Risk for shigh_cor073: PrivacyRisk(value=0.12011234390151512, ci=(0.09918935927935975, 0.14103532852367048))
#
# Running inference attacks on: shigh_cor072
# Risk for shigh_cor072: PrivacyRisk(value=0.08510997165831848, ci=(0.06588889389104219, 0.10433104942559476))
#
# Running inference attacks on: shigh_cor071
# Risk for shigh_cor071: PrivacyRisk(value=0.1236554007756659, ci=(0.10208406516045349, 0.14522673639087832))
#
# Running inference attacks on: shigh_cor070
# Risk for shigh_cor070: PrivacyRisk(value=0.07631059188133149, ci=(0.05707370295167326, 0.09554748081098972))

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
num_plots = len(suffixes)

cols = 4
rows = math.ceil(num_plots / cols)
fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
axes = axes.flatten()  

for idx, suffix in enumerate(suffixes):
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        risks = [res[1].risk().value for res in results]
        secrets = [res[0] for res in results]

        ax = axes[idx]
        ax.bar(x=secrets, height=risks, alpha=0.5, ecolor='black', capsize=10)
        ax.set_xticklabels(secrets, rotation=45, ha='right')
        ax.set_ylabel("Measured inference risk")
        ax.set_xlabel("Secret column")
        ax.set_ylim(0, 1)
        ax.set_title(f"rankcor = 0.{suffix[-2:]}")
    else:
        axes[idx].axis("off") 
        
for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')
# C:\Users\maria\AppData\Local\Temp\ipykernel_38744\3390154485.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(secrets, rotation=45, ha='right')

# %%
suffixes = [f"{i:03d}" for i in range(99, 69, -1)]
rankcors = [int(suffix) / 100 for suffix in suffixes]

secret_columns = [res[0] for res in globals()[f"results{suffixes[0]}"]]

risk_by_secret = {secret: [] for secret in secret_columns}

for suffix in suffixes:
    results_varname = f"results{suffix}"
    if results_varname in globals():
        results = globals()[results_varname]
        for secret, result in results:
            risk_by_secret[secret].append(result.risk().value)
    else:
        for secret in secret_columns:
            risk_by_secret[secret].append(None)  

plt.figure(figsize=(12, 7))

for secret, risks in risk_by_secret.items():
    plt.plot(rankcors, risks, marker='o', label=secret)

plt.xlabel("Rank correlation (rankcor)")
plt.ylabel("Measured inference risk")
plt.title("Inference risk per secret column across decreasing rankcor")
plt.xticks(rankcors)
plt.ylim(0, 1)
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
rankcors = [int(suffix) / 100 for suffix in suffixes]
rankcors_full = [1.00] + rankcors  

risk1_dict = {secret: result.risk().value for secret, result in results1}
risk3_dict = {secret: result.risk().value for secret, result in results3}

risk_by_secret_full = {}

for secret in secret_columns:
    risk_vals = risk_by_secret[secret]
    
    if secret in risk1_dict:
        risk_vals_full = [risk1_dict[secret]] + risk_vals
    else:
        risk_vals_full = [None] + risk_vals
    
    risk_by_secret_full[secret] = risk_vals_full

n = len(secret_columns)
cols = 4
rows = (n + cols - 1) // cols

fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 4 * rows), sharex=True, sharey=True)
axes = axes.flatten()

for idx, secret in enumerate(secret_columns):
    ax = axes[idx]
    
    ax.plot(rankcors_full, risk_by_secret_full[secret], marker='o', color='steelblue', label='Synthesizer with rankcor = [0.7,1.0]')

    if secret in risk3_dict:
        ax.axhline(y=risk3_dict[secret], color='green', linestyle='--', label='Synthpop')
    
    ax.set_title(f"Secret: {secret}")
    ax.set_ylim(0, 1)
    ax.set_xlabel("Rank Correlation")
    ax.set_ylabel("Privacy Risk")
    ax.grid(True)

    if idx == 0:
        ax.legend()

for j in range(idx + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()
